# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/datafyresearcher/datafy-llm-workshop/blob/main/notebooks/0_Preparing_setup_datafy_llm.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # DATAFY LLM Models: Initial Setup

# %% [markdown]
# ## Pre-Requisite
#
# 1. GitHub Account: For the https://github.com/datafyresearcher/datafy-llm-workshop
# 2. Google Account: For Google Colab and Google Drive
#
# ## 💻 Generate API Keys
#
# ```
# OPENAI_API_KEY: sk-8uD5bFYNvr8NsEwA8KbVT3BlbkFJTmgOXt2q-------
#
# HUGGINGFACEHUB_API_TOKEN: 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
#
# ALEPH_ALPHA_API_KEY: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoxODY1OSwidG9rZW5faWQiOjMzMDF9.rgrDlH7ijtqVoZl0VNb0mnAOrkWkcm9a-SDrNg35EpQ
#
# AI21_API_KEY: nuKmvcYWXu5sFfnGcat1RLKLVNW24kRY
#
# ```
#
#
# `dotenv` can also be used to setup the key. Use the `env.example` to create `env` file

# %% [markdown]
# Google Colab offer free GPU therefore, running on Google Colab is prefferd method
#
# 1. To get started, you need to mount your Google Drive in Colab. You can do this by running the following command:

# %%
# Mount the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Once your Drive is mounted, you can clone a repository by running the following command:

# %%
# clone onces
# !git clone https://github.com/datafyresearcher/datafy-llm-workshop.git /content/drive/MyDrive/datafy-llm-workshop
# Out:
# Cloning into '/content/drive/MyDrive/datafy-llm-workshop'...
# remote: Enumerating objects: 171, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 171 (delta 29), reused 10 (delta 7), pack-reused 116
# Receiving objects: 100% (171/171), 80.44 MiB | 14.69 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
# !ls
# Out:
# docker-compose.yml  LICENSE    poetry.lock  pyproject.toml  requirements.txt
# Dockerfile	    notebooks  poetry.toml  README.md

# %%
# %cd drive/MyDrive/datafy-llm-workshop
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/datafy-llm-workshop'
# /content/drive/MyDrive/datafy-llm-workshop

# %%
# %pwd
# Out:
# '/content/driveee/MyDrive/datafy-llm-workshop'

# %%
# !ls
# Out:
# docker-compose.yml  LICENSE    poetry.lock  pyproject.toml  requirements.txt
# Dockerfile	    notebooks  poetry.toml  README.md
